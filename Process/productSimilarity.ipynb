# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import re

# %%
product_df = pd.read_csv('../data/updated_products.csv')
category = pd.read_csv('../data/category.csv')

# %%
len(product_df)
# Out:
# 550313

# %%
category['main_category'].unique().length
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 category['main_category'].unique().length
#
# AttributeError: 'numpy.ndarray' object has no attribute 'length'

# %%
image_urls = product_df['image'].drop_duplicates()
image_urls.to_csv('../model/images.csv')

# %%
print(len(image_urls))
# Out:
# 461166

# %%
nums = image_urls.apply(lambda x: 1 if str(x).endswith('.png') or str(x).endswith('.jpg') else 0).sum()

# %%
print(nums)
# Out:
# 461165

# %%
num = product_df['price'].apply(lambda x: bool(re.match(r'^₹\d{1,3}(,\d{3})*$', str(x)))).sum()
product_df['price'] = product_df['price'].apply(lambda x: float(str(x)[1:].replace(',','.')) if bool(re.match(r'^₹\d{1,3}(,\d{3})*$', str(x))) else 0)

# %%
product_df.head()
# Out:
#    Unnamed: 0                                               name  \
# 0           0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1           1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2           2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3           3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4           4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#
#                                                image rating rating_count  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...    4.2        2,255
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...    4.2        2,948
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...    4.2        1,206
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...    4.0           69
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...    4.1          630
#
#    price  category  price_id  comment_count  details  id
# 0  58.99       0.0       NaN              0      NaN   8
# ...

# %%
product_df['price'] = product_df['price'].apply(lambda x: mean if x == 0 else x)
# Out:
#                                                 name  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#
#                                                image rating rating_count  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...    4.2        2,255
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...    4.2        2,948
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...    4.2        1,206
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...    4.0           69
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...    4.1          630
#
#    price  category  price_id  comment_count  details  id
# 0  58.99       NaN       NaN              0      NaN   8
# 1  75.99       NaN       NaN              0      NaN   9
# ...

# %%
print(product_df['price'].astype(str).str.startswith('₹').sum())
print(product_df['price'].isnull().sum())
print(len(product_df))
product_df.head()
# Out:
# 533772
# 17813
# 551585
#                                                 name  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#
#                                                image rating rating_count  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...    4.2        2,255
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...    4.2        2,948
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...    4.2        1,206
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...    4.0           69
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...    4.1          630
#
#      price  category  price_id  comment_count  details  id
# 0  ₹58,990       NaN       NaN              0      NaN   8
# 1  ₹75,990       NaN       NaN              0      NaN   9
# ...

# %%
product_df['price'] = product_df['price'].apply(
    lambda x: float(str(x)[1:].replace(',', '.')) if str(x).startswith('₹') else 0
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 product_df['price'] = product_df['price'].apply(
#       2     lambda x: float(str(x)[1:].replace(',', '.')) if str(x).startswith('₹') else 0
#       3 )
#
# File d:\E-commerce-Recommendation-System\pythonenv\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
# ...

# %%
product_df.head()
# Out:
#                                                 name  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#
#                                                image rating rating_count  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...    4.2        2,255
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...    4.2        2,948
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...    4.2        1,206
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...    4.0           69
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...    4.1          630
#
#    price  category  price_id  comment_count  details  id
# 0      0       NaN       NaN              0      NaN   8
# 1      0       NaN       NaN              0      NaN   9
# ...

# %%
product_df['id'] = product_df['id'] + 8

# %%
product_df.to_csv('../model/updated_products.csv',index=False)

# %%
product_df.drop(columns=['Unnamed: 0'])
# Out:
#                                                      name  \
# 0       Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1       LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2       LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3       LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4       Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
# ...                                                   ...
# 550308                Adidas Regular Fit Men's Track Tops
# 550309          Redwolf Noice Toit Smort - Hoodie (Black)
# 550310     Redwolf Schrute Farms B&B - Hoodie (Navy Blue)
# 550311                                    Puma Men Shorts
# 550312  Mothercare Printed Cotton Elastane Girls Infan...
#
#                                                     image rating rating_count  \
# 0       https://m.media-amazon.com/images/I/31UISB90sY...    4.2        2,255
# 1       https://m.media-amazon.com/images/I/51JFb7FctD...    4.2        2,948
# ...

# %%
product_df = pd.read_csv('../model/Amazon-Products.csv')
data = product_df[['name','main_category']]
data['name'] = product_df['name'].str.replace('''[^\w\d\s]''','',regex=True)

main_category_encoder = LabelEncoder()
data['main_category_encoded'] = main_category_encoder.fit_transform(data['main_category'])

data.head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25852\3326278479.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['name'] = product_df['name'].str.replace('''[^\w\d\s]''','',regex=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25852\3326278479.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['main_category_encoded'] = main_category_encoder.fit_transform(data['main_category'])
#                                                 name main_category  \
# ...
